# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
df = pd.read_csv('../data/partA.csv')

# %%
df
# Out:
#     x    y     V    x1   y1    x2   y2    x3   y3    x4   y4    x5   y5
# 0   0 -7.0  0.11 -11.4 -3.1 -11.8 -0.7 -12.2  1.7 -12.1  4.1 -10.5 -0.7
# 1   0 -6.5  0.18  -7.8 -2.8 -10.4 -0.7 -11.3  1.7 -10.2  3.6  -8.5 -0.7
# 2   0 -6.0  0.28  -6.8 -2.8  -8.2 -0.7  -9.6  1.5  -8.5  3.5  -7.6 -0.7
# 3   0 -5.5  0.38  -4.5 -2.8  -6.5 -0.7  -7.6  1.4  -6.8  3.3  -6.1 -0.7
# 4   0 -5.0  0.49  -3.0 -2.8  -3.8 -0.8  -6.0  1.3  -5.1  3.2  -4.9 -0.8
# 5   0 -4.5  0.61  -1.1 -2.8  -1.1 -0.8  -4.5  1.3  -3.6  3.2  -3.1 -0.8
# 6   0 -4.0  0.72  -0.1 -2.8   0.3 -0.8  -2.1  1.3  -1.8  3.2  -0.7 -0.8
# 7   0 -3.5  0.86   1.0 -2.8   1.4 -0.7  -0.9  1.3  -0.1  3.2   1.1 -0.8
# 8   0 -3.0  0.97   1.8 -2.8   3.4 -0.8   0.5  1.2   1.0  3.2   2.2 -0.8
# 9   0 -2.5  1.09   4.0 -2.9   5.0 -0.8   2.1  1.2   4.2  3.1   3.7 -0.8
# 10  0 -2.0  1.21   5.0 -2.9   7.6 -0.8   3.3  1.2   6.5  3.2   5.1 -0.8
# 11  0 -1.5  1.33   6.2 -2.9  11.4 -0.9   5.4  1.3   8.1  3.3   6.4 -0.8
# 12  0 -1.0  1.43   8.5 -3.0   NaN  NaN   7.0  1.3   9.1  3.4   7.8 -0.8
# 13  0 -0.5  1.57  11.2 -3.3   NaN  NaN   8.8  1.3  10.7  3.6   9.4 -0.9
# 14  0  0.0  1.70  13.4 -3.6   NaN  NaN  10.6  1.4  11.6  3.7  10.9 -0.9
# 15  0  0.5  1.81   NaN  NaN   NaN  NaN  12.1  1.5   NaN  NaN  12.2 -1.0
# 16  0  1.0  1.94   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 17  0  1.5  2.06   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 18  0  2.0  2.19   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 19  0  2.5  2.32   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 20  0  3.0  2.45   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 21  0  3.5  2.58   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 22  0  4.0  2.71   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 23  0  4.5  2.84   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 24  0  5.0  2.96   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 25  0  5.5  3.09   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 26  0  6.0  3.22   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 27  0  6.5  3.33   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN
# 28  0  7.0  3.55   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN   NaN  NaN

# %%
plt.scatter(df['y'],df['V'],s=16,label='data',zorder=2)
m,c = np.polyfit(df['y'],df['V'],1)
plt.plot(df['y'],m*df['y']+c,label='polyfit',color='red',zorder=1)
plt.xlabel('d (cm)')
plt.ylabel('Potential (V)')
plt.legend()
plt.show()
print(m)
# Out:
# 0.24564532019704444

# %%
v = [1,1.5,2,2.5,1.5]
e = 0.2

# %%
rectangle1 = patches.Rectangle((-11, -7), 22, 1, color="grey",label='electrode')
rectangle2 = patches.Rectangle((-11, 7), 22, 1, color="grey")
for i in range(1,5):
    # plt.errorbar(df[f'x{i}'],df[f'y{i}'], xerr=e, yerr=e,fmt='None',color='black',zorder=1)
    
    plt.scatter(df[f'x{i}'],df[f'y{i}'],s=16)
    plt.plot(df[f'x{i}'],df[f'y{i}'],label=f'{v[i-1]} V')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.gca().add_patch(rectangle1)
plt.gca().add_patch(rectangle2)
plt.legend(bbox_to_anchor=(1, 1))
plt.show()
